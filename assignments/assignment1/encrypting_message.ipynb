# %%
from pathlib import Path

from Crypto.Cipher import PKCS1_OAEP
from Crypto.PublicKey import RSA

# Search for key files starting from current directory and moving up
def find_project_root():
    current = Path.cwd()
    return current  # Default to current if not found

PROJECT_FOLDER = find_project_root()

PUBLIC_KEY_FILE = "ceu_key.pub"

with open(PUBLIC_KEY_FILE, 'r', encoding='utf8') as pub_file:
    public_key = RSA.import_key(pub_file.read())


secret_message = "Hopefully we get perfect score".encode("utf-8")

public_key_cipher = PKCS1_OAEP.new(public_key)

encrypted_message = public_key_cipher.encrypt(secret_message)


ENCRYPTED_MESSAGE_FILE = PROJECT_FOLDER / "encrypted_message.bin"
with open(ENCRYPTED_MESSAGE_FILE, "wb") as f:
    f.write(encrypted_message)

print(f"Encrypted message: {secret_message}")
print(f"Public key:\n{public_key.export_key().decode('utf-8')}")
# Out:
# Encrypted message: b'Hopefully we get perfect score'
# Public key:
# -----BEGIN PUBLIC KEY-----
# MIIBojANBgkqhkiG9w0BAQEFAAOCAY8AMIIBigKCAYEAknhNJrPKetmOPRkIy+JL
# Q/eKofoFUVQGgCcoGaA1sk/3y7zWDIqlE3VJ9lONh1QMc56qUaehLBzhAgl+JaMU
# 0VGWy118eBRPIRYMeUJQnNqclIWCtSKmAkh9yxPOXhvITRRxfNQM6fAO6WPN/5lR
# R6lJMIrhF2PQWwfxvsa7+K7U428lFHKcnDY6sYJQD/qwJYmYj9vLLgkYCzgBQT+E
# hzeufZUnYE+hVdvlo1XwU3uTByfYC0pYRY7g3XfxoT3Ya6zKqdBbAVCDiRbi3fPU
# b2TnBtSZFqqVTIgLbQQkbsF/+Yb8cYQ3Kxzn+xIWcTnffDmDfo/sWQPbVqKcghvk
# BBAZmNcK7jyXxgQpEh7ILJyhTBu3DEBZCh4Ek/nbOANfKuXvCMl6CV1FRnpHcaqo
# XGE9UT3CO5rC07EyzfQMslKwbHTDRg3KkkmiiGKBVPpB9eFPgeMgB4kpl1zShJ82
# 2H3ZzVGGmXlTmyXIQipXj/NQOYwCXoL+ok1FOQP7k1XtAgMBAAE=
# -----END PUBLIC KEY-----
