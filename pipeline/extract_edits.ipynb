# %% [markdown]
# # Wikipedia Edits Data Pipeline
#
# This notebook demonstrates a simple ETL pipeline that:
# 1. Extracts data from the Wikipedia REST API
# 2. Transforms it to JSON Lines format
# 3. Uploads directly to S3

# %% [markdown]
# ## Choose Your Username
#
# Pick a unique username (e.g., your name or initials) and use it consistently:
#
# - **S3 Bucket**: `<username>-wikidata` (e.g., `johndoe-wikidata`)
# - **Athena Database**: `<username>` (e.g., `johndoe`)
# - **Lambda**: Use the same `<username>-wikidata` bucket
#
# **Important:** No hyphens in database names! Use underscores if needed (e.g., `john_doe`).

# %%
# Set your username here - use it consistently across all resources
USERNAME = "palbence"

# %% [markdown]
# ## Setup and Imports

# %%
import datetime
import json
import pprint as pp

import boto3
import requests

# %% [markdown]
# ## Extract: Retrieve Data from Wikipedia API
#
# We use the Wikimedia Analytics API to fetch the most edited pages for a specific date. The API returns JSON with page titles and edit counts.
#
# **API Documentation:** https://doc.wikimedia.org/generated-data-platform/aqs/analytics-api/reference/edits.html

# %%
# Try different dates to see how the data changes
DATE_PARAM = "2025-11-28"

date = datetime.datetime.strptime(DATE_PARAM, "%Y-%m-%d")

# Construct the API URL
url = f"https://wikimedia.org/api/rest_v1/metrics/edited-pages/top-by-edits/en.wikipedia/user/content/{date.strftime('%Y/%m/%d')}"
print(f"Requesting REST API URL: {url}")

# Make the API request
wiki_server_response = requests.get(url, headers={"User-Agent": "curl/7.68.0"})
wiki_response_status = wiki_server_response.status_code
wiki_response_body = wiki_server_response.text

print(f"Wikipedia REST API Response body: {wiki_response_body[:500]}...")
print(f"Wikipedia REST API Response Code: {wiki_response_status}")

# Validate response
if wiki_response_status != 200:
    raise Exception(f"Received non-OK status code from Wiki Server: {wiki_response_status}")
print(f"Successfully retrieved Wikipedia data, content-length: {len(wiki_response_body)}")
# Out:
# Requesting REST API URL: https://wikimedia.org/api/rest_v1/metrics/edited-pages/top-by-edits/en.wikipedia/user/content/2025/11/28
# Wikipedia REST API Response body: {"items":[{"project":"en.wikipedia","editor-type":"user","page-type":"content","granularity":"daily","results":[{"timestamp":"2025-11-28T00:00:00.000Z","top":[{"page_title":"Wang_Fuk_Court_fire","edits":259,"rank":1},{"page_title":"2025_MAMA_Awards","edits":129,"rank":2},{"page_title":"2026_AFC_U-17_Asian_Cup_qualification","edits":105,"rank":3},{"page_title":"2026_Bangladesh_Premier_League_player_auction","edits":95,"rank":4},{"page_title":"Druzhkivka","edits":84,"rank":5},{"page_title":"2025_S...
# Wikipedia REST API Response Code: 200
# Successfully retrieved Wikipedia data, content-length: 6502

# %% [markdown]
# ## Transform: Process Raw Data into JSON Lines
#
# Convert the raw API response into a structured JSON Lines format suitable for analytics. Each line is a valid JSON object representing one page's edit statistics.

# %%
# Parse the API response and extract top edits
wiki_response_parsed = wiki_server_response.json()
top_edits = wiki_response_parsed["items"][0]["results"][0]["top"]

# Transform to JSON Lines format
current_time = datetime.datetime.now(datetime.timezone.utc)
json_lines = ""
for page in top_edits[:5]:
    record = {
        "title": page["page_title"],
        "edits": page["edits"],
        "date": date.strftime("%Y-%m-%d"),
        "retrieved_at": current_time.replace(tzinfo=None).isoformat(),
    }
    json_lines += json.dumps(record) + "\n"

print(f"Transformed {len(top_edits)} records to JSON Lines")
print(f"First few lines:\n{json_lines[:500]}...")
# Out:
# Transformed 100 records to JSON Lines
# First few lines:
# {"title": "Wang_Fuk_Court_fire", "edits": 259, "date": "2025-11-28", "retrieved_at": "2025-12-10T17:56:26.627160"}
# {"title": "2025_MAMA_Awards", "edits": 129, "date": "2025-11-28", "retrieved_at": "2025-12-10T17:56:26.627160"}
# {"title": "2026_AFC_U-17_Asian_Cup_qualification", "edits": 105, "date": "2025-11-28", "retrieved_at": "2025-12-10T17:56:26.627160"}
# {"title": "2026_Bangladesh_Premier_League_player_auction", "edits": 95, "date": "2025-11-28", "retrieved_at": "2025-12-10T17:56:26.627160"}
# ...

# %%
wiki_response_parsed["items"][0]
# Out:
# {'project': 'en.wikipedia',
#  'editor-type': 'user',
#  'page-type': 'content',
#  'granularity': 'daily',
#  'results': [{'timestamp': '2025-11-28T00:00:00.000Z',
#    'top': [{'page_title': 'Wang_Fuk_Court_fire', 'edits': 259, 'rank': 1},
#     {'page_title': '2025_MAMA_Awards', 'edits': 129, 'rank': 2},
#     {'page_title': '2026_AFC_U-17_Asian_Cup_qualification',
#      'edits': 105,
#      'rank': 3},
#     {'page_title': '2026_Bangladesh_Premier_League_player_auction',
#      'edits': 95,
#      'rank': 4},
#     {'page_title': 'Druzhkivka', 'edits': 84, 'rank': 5},
#     {'page_title': '2025_Syed_Modi_International', 'edits': 71, 'rank': 6},
#     {'page_title': '2025_Washington,_D.C.,_National_Guard_shooting',
#      'edits': 70,
#      'rank': 7},
#     {'page_title': 'Odessa_pogroms', 'edits': 68, 'rank': 8},
#     {'page_title': 'Cyclone_Senyar', 'edits': 64, 'rank': 9},
#     {'page_title': 'Multinational_Force_–_Ukraine', 'edits': 60, 'rank': 10},
#     {'page_title': 'Deaths_in_2025', 'edits': 58, 'rank': 11},
#     {'page_title': 'Holyman_family', 'edits': 58, 'rank': 12},
#     {'page_title': '2012_Colorado_Senate_election', 'edits': 57, 'rank': 13},
#     {'page_title': 'Pete_Seeger_discography', 'edits': 57, 'rank': 14},
#     {'page_title': 'NCAA_Season_101_basketball_tournaments',
#      'edits': 55,
#      'rank': 15},
#     {'page_title': '2014_New_Hampshire_Senate_election',
#      'edits': 54,
#      'rank': 16},
#     {'page_title': "2025_Women's_Handball_World_Championship",
#      'edits': 50,
#      'rank': 17},
#     {'page_title': 'Bob_Didier', 'edits': 48, 'rank': 18},
#     {'page_title': "FitzGerald's_Nightclub", 'edits': 47, 'rank': 19},
#     {'page_title': 'Mastercooks_of_Belgium', 'edits': 45, 'rank': 20},
#     {'page_title': 'Guild', 'edits': 44, 'rank': 21},
#     {'page_title': 'Analytic_philosophy', 'edits': 43, 'rank': 22},
#     {'page_title': 'Bob_Hansen', 'edits': 42, 'rank': 23},
#     {'page_title': 'Hunter_Dickinson', 'edits': 42, 'rank': 24},
#     {'page_title': 'Bold_hypothesis', 'edits': 41, 'rank': 25},
#     {'page_title': 'GMD_GMDH-1', 'edits': 41, 'rank': 26},
#     {'page_title': 'Princess_Milica_of_Montenegro', 'edits': 41, 'rank': 27},
#     {'page_title': 'William_Holyman', 'edits': 41, 'rank': 28},
#     {'page_title': 'Yeom_Hye-ran', 'edits': 41, 'rank': 29},
#     {'page_title': "2025–26_BYU_Cougars_women's_basketball_team",
#      'edits': 39,
#      'rank': 30},
#     {'page_title': 'Tony_Moss', 'edits': 39, 'rank': 31},
#     {'page_title': 'Alexander_Hamilton_Swan', 'edits': 38, 'rank': 32},
#     {'page_title': 'Bharatiya_Janata_Party_–_Haryana',
#      'edits': 38,
#      'rank': 33},
#     {'page_title': 'List_of_music_genres_and_styles', 'edits': 38, 'rank': 34},
#     {'page_title': '2025_WDF_World_Darts_Championship',
#      'edits': 37,
#      'rank': 35},
#     {'page_title': 'List_of_Outlaw_Star_characters', 'edits': 37, 'rank': 36},
#     {'page_title': 'Udit_Narayan', 'edits': 37, 'rank': 37},
#     {'page_title': "2025_Men's_FIH_Hockey_Junior_World_Cup",
#      'edits': 36,
#      'rank': 38},
#     {'page_title': "St._Joseph's_the_Worker_Church_(Belgrade)",
#      'edits': 36,
#      'rank': 39},
#     {'page_title': 'Tuan_Leekpai', 'edits': 36, 'rank': 40},
#     {'page_title': '2025_Pacific_typhoon_season', 'edits': 35, 'rank': 41},
#     {'page_title': 'Legalism_(Chinese_philosophy)', 'edits': 34, 'rank': 42},
#     {'page_title': 'Polish_Figure_Skating_Championships',
#      'edits': 34,
#      'rank': 43},
#     {'page_title': 'Tere_Ishk_Mein', 'edits': 34, 'rank': 44},
#     {'page_title': 'Bigg_Boss_(Hindi_TV_series)_season_19',
#      'edits': 33,
#      'rank': 45},
#     {'page_title': 'Guatemala–Ukraine_relations', 'edits': 33, 'rank': 46},
#     {'page_title': 'Hither_Green_Cemetery', 'edits': 33, 'rank': 47},
#     {'page_title': 'John_Clay_(cattleman)', 'edits': 33, 'rank': 48},
#     {'page_title': 'The_Voice_of_Germany_season_15', 'edits': 33, 'rank': 49},
#     {'page_title': 'Farida_Sulaiman', 'edits': 32, 'rank': 50},
#     {'page_title': 'Horovod_(machine_learning)', 'edits': 32, 'rank': 51},
#     {'page_title': 'Laudatio_Turiae', 'edits': 32, 'rank': 52},
#     {'page_title': 'List_of_heads_of_former_ruling_families',
#      'edits': 32,
#      'rank': 53},
#     {'page_title': 'List_of_high_schools_in_Indiana', 'edits': 32, 'rank': 54},
#     {'page_title': 'Poecilia_vandepolli', 'edits': 32, 'rank': 55},
#     {'page_title': 'Begging_in_Pakistan', 'edits': 31, 'rank': 56},
#     {'page_title': 'KBL_All-Star_Game', 'edits': 31, 'rank': 57},
#     {'page_title': 'List_of_composers_by_nationality',
#      'edits': 31,
#      'rank': 58},
#     {'page_title': 'Upper_Murray_Football_Netball_League',
#      'edits': 31,
#      'rank': 59},
#     {'page_title': '2026_CPL–U_Sports_Draft', 'edits': 29, 'rank': 60},
#     {'page_title': 'Ambam_(gorilla)', 'edits': 29, 'rank': 61},
#     {'page_title': 'Department_of_Government_Efficiency',
#      'edits': 29,
#      'rank': 62},
#     {'page_title': 'I_Deliver_Parcels_in_Beijing', 'edits': 29, 'rank': 63},
#     {'page_title': 'Solidcore_Resources', 'edits': 29, 'rank': 64},
#     {'page_title': 'Stranger_Things_season_5', 'edits': 29, 'rank': 65},
#     {'page_title': '2025_ATP_Challenger_Tour', 'edits': 28, 'rank': 66},
#     {'page_title': "2025_ITF_Men's_World_Tennis_Tour_(October–December)",
#      'edits': 28,
#      'rank': 67},
#     {'page_title': 'Al_Finucane', 'edits': 28, 'rank': 68},
#     {'page_title': 'Dhurandhar', 'edits': 28, 'rank': 69},
#     {'page_title': 'Dinis_Incanha', 'edits': 28, 'rank': 70},
#     {'page_title': 'Karate_World_Championships', 'edits': 28, 'rank': 71},
#     {'page_title': 'List_of_Pixar_film_references', 'edits': 28, 'rank': 72},
#     {'page_title': 'List_of_Teletubbies_episodes', 'edits': 28, 'rank': 73},
#     {'page_title': 'Nikon_Z-mount', 'edits': 28, 'rank': 74},
#     {'page_title': 'Verificationism', 'edits': 28, 'rank': 75},
#     {'page_title': 'Adam_Sherriff_Scott', 'edits': 27, 'rank': 76},
#     {'page_title': 'Andrian_Pertout', 'edits': 27, 'rank': 77},
#     {'page_title': 'Die_with_a_Smile', 'edits': 27, 'rank': 78},
#     {'page_title': 'Institut_der_Wirtschaftsprüfer_in_Deutschland',
#      'edits': 27,
#      'rank': 79},
#     {'page_title': 'Kumiho', 'edits': 27, 'rank': 80},
#     {'page_title': 'List_of_female_action_heroes_and_villains',
#      'edits': 27,
#      'rank': 81},
#     {'page_title': 'List_of_people_executed_in_the_United_States_in_1923',
#      'edits': 27,
#      'rank': 82},
#     {'page_title': '2027_FIBA_Basketball_World_Cup_qualification_(Europe)',
#      'edits': 26,
#      'rank': 83},
#     {'page_title': 'First_Assault_on_Rome', 'edits': 26, 'rank': 84},
#     {'page_title': 'Hushmand_Dehqan', 'edits': 26, 'rank': 85},
#     {'page_title': 'Peru_national_football_team_results_(1980–1999)',
#      'edits': 26,
#      'rank': 86},
#     {'page_title': '2025–26_Syed_Mushtaq_Ali_Trophy', 'edits': 25, 'rank': 87},
#     {'page_title': 'Bangladesh_Football_League', 'edits': 25, 'rank': 88},
#     {'page_title': 'FUBB_All-Star_Game', 'edits': 25, 'rank': 89},
#     {'page_title': 'Glossary_of_Russian_carriages', 'edits': 25, 'rank': 90},
#     {'page_title': 'Heinrich_Höfemeier', 'edits': 25, 'rank': 91},
#     {'page_title': 'Thomas_M._Cooley', 'edits': 25, 'rank': 92},
#     {'page_title': 'Dan_Farah', 'edits': 24, 'rank': 93},
#     {'page_title': 'List_of_Canadian_universities_by_endowment',
#      'edits': 24,
#      'rank': 94},
#     {'page_title': 'Maurice_Kanbar', 'edits': 24, 'rank': 95},
#     {'page_title': 'Money_laundering_in_Pakistan', 'edits': 24, 'rank': 96},
#     {'page_title': 'Quantum_Baby', 'edits': 24, 'rank': 97},
#     {'page_title': 'Aṣa_(album)', 'edits': 23, 'rank': 98},
#     {'page_title': "Bangladesh_women's_national_youth_handball_team",
#      'edits': 23,
#      'rank': 99},
#     {'page_title': 'Horta_Inta-A_Na_Man', 'edits': 23, 'rank': 100}]}]}

# %% [markdown]
# ---
# ## Lab 1: Create an S3 Bucket
#
# **Task:** Create an S3 bucket for the Wikipedia data pipeline.
#
# **Requirements:**
# - Bucket name: `<username>-wikidata` (use your USERNAME from above)
# - Create the bucket if it doesn't exist
#
# **Documentation:** [create_bucket](https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/s3/client/create_bucket.html)

# %%
S3_WIKI_BUCKET = "palbence-wikidata"
s3 = boto3.client("s3")

bucket_names = [bucket["Name"] for bucket in s3.list_buckets()["Buckets"]]
if S3_WIKI_BUCKET not in bucket_names:
    # LAB 1: Create the bucket if it doesn't exist
    # YOUR SOLUTION COMES HERE =========================
    default_region = "eu-west-1"

    try:
        bucket_configuration = {"LocationConstraint": default_region}
        response = s3.create_bucket(Bucket=S3_WIKI_BUCKET, CreateBucketConfiguration=bucket_configuration)
        print("\n📦 AWS Response:")
        pp.pprint(response)

        if response["ResponseMetadata"]["HTTPStatusCode"] == 200:
            print(f"\n✅ Success! Bucket {S3_WIKI_BUCKET} created in {default_region}")
    except Exception as e:
        print(f"❌ Error creating bucket: {str(e)}")
    # ==================================================
    print(f"Created new bucket: {S3_WIKI_BUCKET}")
else:
    print(f"Using existing bucket: {S3_WIKI_BUCKET}")
# Out:
# Using existing bucket: palbence-wikidata

# %%
# Test Lab 1
assert USERNAME != "<username>", "Please set your USERNAME at the top of the notebook"
assert S3_WIKI_BUCKET.endswith("-wikidata"), "Bucket name must end with '-wikidata'"

try:
    s3.head_bucket(Bucket=S3_WIKI_BUCKET)
    print(f"Bucket {S3_WIKI_BUCKET} exists!")
except Exception as e:
    print(f"Bucket {S3_WIKI_BUCKET} not found: {e}")
    raise
# Out:
# Bucket palbence-wikidata exists!

# %% [markdown]
# ---
# ## Lab 2: Upload JSON Lines to S3
#
# **Task:** Upload the `json_lines` data directly to S3 (no local file!).
#
# **Requirements:**
# - Use `s3.put_object()` to upload the data directly
# - Place the file under `raw-edits/` prefix in S3
# - File name: `raw-edits-YYYY-MM-DD.json` (use the date from `DATE_PARAM`)
#
# **Example S3 path:** `s3://johndoe-wikidata/raw-edits/raw-edits-2025-11-25.json`
#
# **Documentation:** [put_object](https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/s3/client/put_object.html)

# %%
# LAB 2: Upload json_lines directly to S3
# YOUR SOLUTION COMES HERE =========================
s3_key = f"raw-edits/raw-edits-{date.strftime('%Y-%m-%d')}.json"
try:
    s3.put_object(
        Bucket=S3_WIKI_BUCKET,
        Key=s3_key,
        Body=json_lines,
    )

    print(f"✅ Successfully uploaded data to s3://{S3_WIKI_BUCKET}/{s3_key}")

except Exception as e:
    print(f"❌ Error uploading data: {str(e)}")

# ==================================================
# Out:
# ✅ Successfully uploaded data to s3://palbence-wikidata/raw-edits/raw-edits-2025-11-28.json

# %%
# Test Lab 2
expected_key = f"raw-edits/raw-edits-{date.strftime('%Y-%m-%d')}.json"
try:
    s3.head_object(Bucket=S3_WIKI_BUCKET, Key=expected_key)
    print(f"File uploaded successfully to s3://{S3_WIKI_BUCKET}/{expected_key}")
except Exception as e:
    print(f"File not found at s3://{S3_WIKI_BUCKET}/{expected_key}")
    raise
# Out:
# File uploaded successfully to s3://palbence-wikidata/raw-edits/raw-edits-2025-11-28.json
